# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv('main.csv')

# %%
df.head()
# Out:
#    BindingDB Reactant_set_id  \
# 0                   50424424
# 1                   51140403
# 2                   50782228
# 3                     381845
# 4                   51290692
#
#                                        Ligand SMILES  \
# 0  CC(C)(C)OC(=O)Nc1ccc(cc1)-c1cc(no1)C(=O)NCCCCC...
# 1  Cl.CC(=O)Nc1ccc(cc1)-c1ccnc(Nc2ccc(NC(=O)CCCCC...
# 2  ONC(=O)CCCCCCC(=O)Nc1ccc(NCCCn2cc(cn2)-c2ncnc3...
# 3     CS(=O)(=O)NCCc1cn(Cc2ccc(cc2)C(=O)NO)c2ccccc12
# 4  CC(C)(C)OC(=O)Nc1cccc(c1)-c1csc(NC(=O)CCCCCC(=...
#
#                                         Ligand InChI  \
# 0  InChI=1S/C22H30N4O6/c1-22(2,3)31-21(29)24-16-1...
# 1  InChI=1S/C26H30N6O4/c1-18(33)28-20-10-8-19(9-1...
# 2  InChI=1S/C26H32N8O3/c35-23(6-3-1-2-4-7-24(36)3...
# 3  InChI=1S/C19H21N3O4S/c1-27(25,26)20-11-10-16-1...
# 4  InChI=1S/C21H28N4O5S/c1-21(2,3)30-20(28)22-15-...
#
#               Ligand InChI Key  BindingDB MonomerID  \
# 0  WWGBHDIHIVGYLZ-UHFFFAOYSA-N             50261816
# 1  JWHCLMFMTWUFGU-UHFFFAOYSA-N             50467405
# 2  AMPZODPRXQXGKA-UHFFFAOYSA-N             50250140
# 3  LJQMJXUXIFRYLN-UHFFFAOYSA-N               218187
# 4  FXKMDFMOXSKKIB-UHFFFAOYSA-N             50526157
#
#                                BindingDB Ligand Name  \
# 0  CHEMBL511749::tert-butyl 4-(3-((7-(hydroxyamin...
# 1                                      CHEMBL4290831
# 2                                      CHEMBL4098975
# 3                                      US9249087, 30
# 4                                      CHEMBL4550526
#
#   Target Name Assigned by Curator or DataSource  \
# 0                Cereblon/Histone deacetylase 6
# 1                Cereblon/Histone deacetylase 6
# 2                Cereblon/Histone deacetylase 6
# 3                Cereblon/Histone deacetylase 6
# 4                Cereblon/Histone deacetylase 6
#
#   Target Source Organism According to Curator or DataSource  Ki (nM)  \
# 0                                       Homo sapiens             NaN
# 1                                       Homo sapiens             NaN
# 2                                       Homo sapiens             NaN
# 3                                       Homo sapiens             NaN
# 4                                       Homo sapiens             NaN
#
#    IC50 (nM)  ...  UniProt (SwissProt) Recommended Name of Target Chain  \
# 0      0.002  ...                              Histone deacetylase 6
# 1        0.1  ...                              Histone deacetylase 6
# 2       0.14  ...                              Histone deacetylase 6
# 3       0.17  ...                              Histone deacetylase 6
# 4  <0.170000  ...                              Histone deacetylase 6
#
#    UniProt (SwissProt) Entry Name of Target Chain  \
# 0                                     HDAC6_HUMAN
# 1                                     HDAC6_HUMAN
# 2                                     HDAC6_HUMAN
# 3                                     HDAC6_HUMAN
# 4                                     HDAC6_HUMAN
#
#    UniProt (SwissProt) Primary ID of Target Chain  \
# 0                                          Q9UBN7
# 1                                          Q9UBN7
# 2                                          Q9UBN7
# 3                                          Q9UBN7
# 4                                          Q9UBN7
#
#    UniProt (SwissProt) Secondary ID(s) of Target Chain  \
# 0                        O94975,Q6NT75,Q7L3E5,Q96CY0
# 1                        O94975,Q6NT75,Q7L3E5,Q96CY0
# 2                        O94975,Q6NT75,Q7L3E5,Q96CY0
# 3                        O94975,Q6NT75,Q7L3E5,Q96CY0
# 4                        O94975,Q6NT75,Q7L3E5,Q96CY0
#
#    UniProt (SwissProt) Alternative ID(s) of Target Chain  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   UniProt (TrEMBL) Submitted Name of Target Chain  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   UniProt (TrEMBL) Entry Name of Target Chain  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   UniProt (TrEMBL) Primary ID of Target Chain  \
# 0                                  A0A024QZ26
# 1                                  A0A024QZ26
# 2                                  A0A024QZ26
# 3                                  A0A024QZ26
# 4                                  A0A024QZ26
#
#    UniProt (TrEMBL) Secondary ID(s) of Target Chain  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    UniProt (TrEMBL) Alternative ID(s) of Target Chain
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 49 columns]

# %%
df
# Out:
#       BindingDB Reactant_set_id  \
# 0                      50424424
# 1                      51140403
# 2                      50782228
# 3                        381845
# 4                      51290692
# ...                         ...
# 5888                   50419504
# 5889                   50522401
# 5890                   50692667
# 5891                   50692487
# 5892                     305967
#
#                                           Ligand SMILES  \
# 0     CC(C)(C)OC(=O)Nc1ccc(cc1)-c1cc(no1)C(=O)NCCCCC...
# 1     Cl.CC(=O)Nc1ccc(cc1)-c1ccnc(Nc2ccc(NC(=O)CCCCC...
# 2     ONC(=O)CCCCCCC(=O)Nc1ccc(NCCCn2cc(cn2)-c2ncnc3...
# 3        CS(=O)(=O)NCCc1cn(Cc2ccc(cc2)C(=O)NO)c2ccccc12
# 4     CC(C)(C)OC(=O)Nc1cccc(c1)-c1csc(NC(=O)CCCCCC(=...
# ...                                                 ...
# 5888                        CCOC(=O)SCC(=O)c1ccc(OC)cc1
# 5889  CCOc1ccc(cc1-c1nc2c(CC)nn(C)c2c(=O)[nH]1)C1CC1...
# 5890  CC(C)(C)SC[C@H]1N=C(c2ccccc2)c2ccccc2N(CCCCC(=...
# 5891  NC(=O)C[C@@H]1N=C(c2ccccc2)c2ccccc2N(CCCCC(=O)...
# 5892  C[C@H](CN(C)C(C)C)NC(=O)c1ccc(cc1F)-c1noc(n1)C...
#
#                                            Ligand InChI  \
# 0     InChI=1S/C22H30N4O6/c1-22(2,3)31-21(29)24-16-1...
# 1     InChI=1S/C26H30N6O4/c1-18(33)28-20-10-8-19(9-1...
# 2     InChI=1S/C26H32N8O3/c35-23(6-3-1-2-4-7-24(36)3...
# 3     InChI=1S/C19H21N3O4S/c1-27(25,26)20-11-10-16-1...
# 4     InChI=1S/C21H28N4O5S/c1-21(2,3)30-20(28)22-15-...
# ...                                                 ...
# 5888  InChI=1S/C12H14O4S/c1-3-16-12(14)17-8-11(13)9-...
# 5889  InChI=1S/C20H23N5O4/c1-4-14-16-17(25(3)23-14)2...
# 5890  InChI=1S/C25H31N3O3S/c1-25(2,3)32-17-20-24(30)...
# 5891  InChI=1S/C22H24N4O4/c23-19(27)14-17-22(29)26(1...
# 5892  InChI=1S/C17H20F4N4O2/c1-9(2)25(4)8-10(3)22-15...
#
#                  Ligand InChI Key  BindingDB MonomerID  \
# 0     WWGBHDIHIVGYLZ-UHFFFAOYSA-N             50261816
# 1     JWHCLMFMTWUFGU-UHFFFAOYSA-N             50467405
# 2     AMPZODPRXQXGKA-UHFFFAOYSA-N             50250140
# 3     LJQMJXUXIFRYLN-UHFFFAOYSA-N               218187
# 4     FXKMDFMOXSKKIB-UHFFFAOYSA-N             50526157
# ...                           ...                  ...
# 5888  SABHFVXDKFDQPI-UHFFFAOYSA-N             50252623
# 5889  WLWDYOQBVMOJPU-UHFFFAOYSA-N             50196773
# 5890  ZIAMUXVOAZMOPT-HXUWFJFHSA-N             50232989
# 5891  OZNZDDRIRCWDJE-KRWDZBQOSA-N             50232974
# 5892  XIDHNMBDXJJOCG-SNVBAGLBSA-N               162851
#
#                                   BindingDB Ligand Name  \
# 0     CHEMBL511749::tert-butyl 4-(3-((7-(hydroxyamin...
# 1                                         CHEMBL4290831
# 2                                         CHEMBL4098975
# 3                                         US9249087, 30
# 4                                         CHEMBL4550526
# ...                                                 ...
# 5888  CHEMBL470470::O-Ethyl S-2-(4-methoxy-phenyl)-2...
# 5889                                      CHEMBL3908767
# 5890                                      CHEMBL4060342
# 5891                                      CHEMBL4072925
# 5892                                     US9056843, 142
#
#      Target Name Assigned by Curator or DataSource  \
# 0                   Cereblon/Histone deacetylase 6
# 1                   Cereblon/Histone deacetylase 6
# 2                   Cereblon/Histone deacetylase 6
# 3                   Cereblon/Histone deacetylase 6
# 4                   Cereblon/Histone deacetylase 6
# ...                                            ...
# 5888                Cereblon/Histone deacetylase 6
# 5889                Cereblon/Histone deacetylase 6
# 5890                Cereblon/Histone deacetylase 6
# 5891                Cereblon/Histone deacetylase 6
# 5892                Cereblon/Histone deacetylase 6
#
#      Target Source Organism According to Curator or DataSource  Ki (nM)  \
# 0                                          Homo sapiens             NaN
# 1                                          Homo sapiens             NaN
# 2                                          Homo sapiens             NaN
# 3                                          Homo sapiens             NaN
# 4                                          Homo sapiens             NaN
# ...                                                 ...             ...
# 5888                                       Homo sapiens             NaN
# 5889                                       Homo sapiens             NaN
# 5890                                       Homo sapiens             NaN
# 5891                                       Homo sapiens             NaN
# 5892                                       Homo sapiens             NaN
#
#       IC50 (nM)  ...  UniProt (SwissProt) Recommended Name of Target Chain  \
# 0         0.002  ...                              Histone deacetylase 6
# 1           0.1  ...                              Histone deacetylase 6
# 2          0.14  ...                              Histone deacetylase 6
# 3          0.17  ...                              Histone deacetylase 6
# 4     <0.170000  ...                              Histone deacetylase 6
# ...         ...  ...                                                ...
# 5888       5360  ...                              Histone deacetylase 6
# 5889       5370  ...                              Histone deacetylase 6
# 5890       5370  ...                              Histone deacetylase 6
# 5891       5380  ...                              Histone deacetylase 6
# 5892       5400  ...                              Histone deacetylase 6
#
#       UniProt (SwissProt) Entry Name of Target Chain  \
# 0                                        HDAC6_HUMAN
# 1                                        HDAC6_HUMAN
# 2                                        HDAC6_HUMAN
# 3                                        HDAC6_HUMAN
# 4                                        HDAC6_HUMAN
# ...                                              ...
# 5888                                     HDAC6_HUMAN
# 5889                                     HDAC6_HUMAN
# 5890                                     HDAC6_HUMAN
# 5891                                     HDAC6_HUMAN
# 5892                                     HDAC6_HUMAN
#
#       UniProt (SwissProt) Primary ID of Target Chain  \
# 0                                             Q9UBN7
# 1                                             Q9UBN7
# 2                                             Q9UBN7
# 3                                             Q9UBN7
# 4                                             Q9UBN7
# ...                                              ...
# 5888                                          Q9UBN7
# 5889                                          Q9UBN7
# 5890                                          Q9UBN7
# 5891                                          Q9UBN7
# 5892                                          Q9UBN7
#
#       UniProt (SwissProt) Secondary ID(s) of Target Chain  \
# 0                           O94975,Q6NT75,Q7L3E5,Q96CY0
# 1                           O94975,Q6NT75,Q7L3E5,Q96CY0
# 2                           O94975,Q6NT75,Q7L3E5,Q96CY0
# 3                           O94975,Q6NT75,Q7L3E5,Q96CY0
# 4                           O94975,Q6NT75,Q7L3E5,Q96CY0
# ...                                                 ...
# 5888                        O94975,Q6NT75,Q7L3E5,Q96CY0
# 5889                        O94975,Q6NT75,Q7L3E5,Q96CY0
# 5890                        O94975,Q6NT75,Q7L3E5,Q96CY0
# 5891                        O94975,Q6NT75,Q7L3E5,Q96CY0
# 5892                        O94975,Q6NT75,Q7L3E5,Q96CY0
#
#       UniProt (SwissProt) Alternative ID(s) of Target Chain  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5888                                                NaN
# 5889                                                NaN
# 5890                                                NaN
# 5891                                                NaN
# 5892                                                NaN
#
#      UniProt (TrEMBL) Submitted Name of Target Chain  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 5888                                             NaN
# 5889                                             NaN
# 5890                                             NaN
# 5891                                             NaN
# 5892                                             NaN
#
#      UniProt (TrEMBL) Entry Name of Target Chain  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 5888                                         NaN
# 5889                                         NaN
# 5890                                         NaN
# 5891                                         NaN
# 5892                                         NaN
#
#      UniProt (TrEMBL) Primary ID of Target Chain  \
# 0                                     A0A024QZ26
# 1                                     A0A024QZ26
# 2                                     A0A024QZ26
# 3                                     A0A024QZ26
# 4                                     A0A024QZ26
# ...                                          ...
# 5888                                  A0A024QZ26
# 5889                                  A0A024QZ26
# 5890                                  A0A024QZ26
# 5891                                  A0A024QZ26
# 5892                                  A0A024QZ26
#
#       UniProt (TrEMBL) Secondary ID(s) of Target Chain  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 5888                                               NaN
# 5889                                               NaN
# 5890                                               NaN
# 5891                                               NaN
# 5892                                               NaN
#
#       UniProt (TrEMBL) Alternative ID(s) of Target Chain
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5888                                                NaN
# 5889                                                NaN
# 5890                                                NaN
# 5891                                                NaN
# 5892                                                NaN
#
# [5893 rows x 49 columns]

# %%
df['IC50 (nM)']= df['IC50 (nM)'].astype('str')
df['IC50 (nM)'] = df['IC50 (nM)'].str.replace(',', '')
df['IC50 (nM)'] = pd.to_numeric(df['IC50 (nM)'], errors='coerce')

# %%
df1=df['IC50 (nM)']
df1
# Out:
# 0          0.002
# 1          0.100
# 2          0.140
# 3          0.170
# 4            NaN
#           ...
# 5888    5360.000
# 5889    5370.000
# 5890    5370.000
# 5891    5380.000
# 5892    5400.000
# Name: IC50 (nM), Length: 5893, dtype: float64

# %%
df1.dropna()
# Out:
# 0          0.002
# 1          0.100
# 2          0.140
# 3          0.170
# 5          0.200
#           ...
# 5888    5360.000
# 5889    5370.000
# 5890    5370.000
# 5891    5380.000
# 5892    5400.000
# Name: IC50 (nM), Length: 5150, dtype: float64

# %%
df.drop(['IC50 (nM)'],axis=1)
# Out:
#       BindingDB Reactant_set_id  \
# 0                      50424424
# 1                      51140403
# 2                      50782228
# 3                        381845
# 4                      51290692
# ...                         ...
# 5888                   50419504
# 5889                   50522401
# 5890                   50692667
# 5891                   50692487
# 5892                     305967
#
#                                           Ligand SMILES  \
# 0     CC(C)(C)OC(=O)Nc1ccc(cc1)-c1cc(no1)C(=O)NCCCCC...
# 1     Cl.CC(=O)Nc1ccc(cc1)-c1ccnc(Nc2ccc(NC(=O)CCCCC...
# 2     ONC(=O)CCCCCCC(=O)Nc1ccc(NCCCn2cc(cn2)-c2ncnc3...
# 3        CS(=O)(=O)NCCc1cn(Cc2ccc(cc2)C(=O)NO)c2ccccc12
# 4     CC(C)(C)OC(=O)Nc1cccc(c1)-c1csc(NC(=O)CCCCCC(=...
# ...                                                 ...
# 5888                        CCOC(=O)SCC(=O)c1ccc(OC)cc1
# 5889  CCOc1ccc(cc1-c1nc2c(CC)nn(C)c2c(=O)[nH]1)C1CC1...
# 5890  CC(C)(C)SC[C@H]1N=C(c2ccccc2)c2ccccc2N(CCCCC(=...
# 5891  NC(=O)C[C@@H]1N=C(c2ccccc2)c2ccccc2N(CCCCC(=O)...
# 5892  C[C@H](CN(C)C(C)C)NC(=O)c1ccc(cc1F)-c1noc(n1)C...
#
#                                            Ligand InChI  \
# 0     InChI=1S/C22H30N4O6/c1-22(2,3)31-21(29)24-16-1...
# 1     InChI=1S/C26H30N6O4/c1-18(33)28-20-10-8-19(9-1...
# 2     InChI=1S/C26H32N8O3/c35-23(6-3-1-2-4-7-24(36)3...
# 3     InChI=1S/C19H21N3O4S/c1-27(25,26)20-11-10-16-1...
# 4     InChI=1S/C21H28N4O5S/c1-21(2,3)30-20(28)22-15-...
# ...                                                 ...
# 5888  InChI=1S/C12H14O4S/c1-3-16-12(14)17-8-11(13)9-...
# 5889  InChI=1S/C20H23N5O4/c1-4-14-16-17(25(3)23-14)2...
# 5890  InChI=1S/C25H31N3O3S/c1-25(2,3)32-17-20-24(30)...
# 5891  InChI=1S/C22H24N4O4/c23-19(27)14-17-22(29)26(1...
# 5892  InChI=1S/C17H20F4N4O2/c1-9(2)25(4)8-10(3)22-15...
#
#                  Ligand InChI Key  BindingDB MonomerID  \
# 0     WWGBHDIHIVGYLZ-UHFFFAOYSA-N             50261816
# 1     JWHCLMFMTWUFGU-UHFFFAOYSA-N             50467405
# 2     AMPZODPRXQXGKA-UHFFFAOYSA-N             50250140
# 3     LJQMJXUXIFRYLN-UHFFFAOYSA-N               218187
# 4     FXKMDFMOXSKKIB-UHFFFAOYSA-N             50526157
# ...                           ...                  ...
# 5888  SABHFVXDKFDQPI-UHFFFAOYSA-N             50252623
# 5889  WLWDYOQBVMOJPU-UHFFFAOYSA-N             50196773
# 5890  ZIAMUXVOAZMOPT-HXUWFJFHSA-N             50232989
# 5891  OZNZDDRIRCWDJE-KRWDZBQOSA-N             50232974
# 5892  XIDHNMBDXJJOCG-SNVBAGLBSA-N               162851
#
#                                   BindingDB Ligand Name  \
# 0     CHEMBL511749::tert-butyl 4-(3-((7-(hydroxyamin...
# 1                                         CHEMBL4290831
# 2                                         CHEMBL4098975
# 3                                         US9249087, 30
# 4                                         CHEMBL4550526
# ...                                                 ...
# 5888  CHEMBL470470::O-Ethyl S-2-(4-methoxy-phenyl)-2...
# 5889                                      CHEMBL3908767
# 5890                                      CHEMBL4060342
# 5891                                      CHEMBL4072925
# 5892                                     US9056843, 142
#
#      Target Name Assigned by Curator or DataSource  \
# 0                   Cereblon/Histone deacetylase 6
# 1                   Cereblon/Histone deacetylase 6
# 2                   Cereblon/Histone deacetylase 6
# 3                   Cereblon/Histone deacetylase 6
# 4                   Cereblon/Histone deacetylase 6
# ...                                            ...
# 5888                Cereblon/Histone deacetylase 6
# 5889                Cereblon/Histone deacetylase 6
# 5890                Cereblon/Histone deacetylase 6
# 5891                Cereblon/Histone deacetylase 6
# 5892                Cereblon/Histone deacetylase 6
#
#      Target Source Organism According to Curator or DataSource  Ki (nM)  \
# 0                                          Homo sapiens             NaN
# 1                                          Homo sapiens             NaN
# 2                                          Homo sapiens             NaN
# 3                                          Homo sapiens             NaN
# 4                                          Homo sapiens             NaN
# ...                                                 ...             ...
# 5888                                       Homo sapiens             NaN
# 5889                                       Homo sapiens             NaN
# 5890                                       Homo sapiens             NaN
# 5891                                       Homo sapiens             NaN
# 5892                                       Homo sapiens             NaN
#
#       Kd (nM)  ...  UniProt (SwissProt) Recommended Name of Target Chain  \
# 0         NaN  ...                              Histone deacetylase 6
# 1         NaN  ...                              Histone deacetylase 6
# 2         NaN  ...                              Histone deacetylase 6
# 3         NaN  ...                              Histone deacetylase 6
# 4         NaN  ...                              Histone deacetylase 6
# ...       ...  ...                                                ...
# 5888      NaN  ...                              Histone deacetylase 6
# 5889      NaN  ...                              Histone deacetylase 6
# 5890      NaN  ...                              Histone deacetylase 6
# 5891      NaN  ...                              Histone deacetylase 6
# 5892      NaN  ...                              Histone deacetylase 6
#
#       UniProt (SwissProt) Entry Name of Target Chain  \
# 0                                        HDAC6_HUMAN
# 1                                        HDAC6_HUMAN
# 2                                        HDAC6_HUMAN
# 3                                        HDAC6_HUMAN
# 4                                        HDAC6_HUMAN
# ...                                              ...
# 5888                                     HDAC6_HUMAN
# 5889                                     HDAC6_HUMAN
# 5890                                     HDAC6_HUMAN
# 5891                                     HDAC6_HUMAN
# 5892                                     HDAC6_HUMAN
#
#       UniProt (SwissProt) Primary ID of Target Chain  \
# 0                                             Q9UBN7
# 1                                             Q9UBN7
# 2                                             Q9UBN7
# 3                                             Q9UBN7
# 4                                             Q9UBN7
# ...                                              ...
# 5888                                          Q9UBN7
# 5889                                          Q9UBN7
# 5890                                          Q9UBN7
# 5891                                          Q9UBN7
# 5892                                          Q9UBN7
#
#       UniProt (SwissProt) Secondary ID(s) of Target Chain  \
# 0                           O94975,Q6NT75,Q7L3E5,Q96CY0
# 1                           O94975,Q6NT75,Q7L3E5,Q96CY0
# 2                           O94975,Q6NT75,Q7L3E5,Q96CY0
# 3                           O94975,Q6NT75,Q7L3E5,Q96CY0
# 4                           O94975,Q6NT75,Q7L3E5,Q96CY0
# ...                                                 ...
# 5888                        O94975,Q6NT75,Q7L3E5,Q96CY0
# 5889                        O94975,Q6NT75,Q7L3E5,Q96CY0
# 5890                        O94975,Q6NT75,Q7L3E5,Q96CY0
# 5891                        O94975,Q6NT75,Q7L3E5,Q96CY0
# 5892                        O94975,Q6NT75,Q7L3E5,Q96CY0
#
#      UniProt (SwissProt) Alternative ID(s) of Target Chain  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5888                                                NaN
# 5889                                                NaN
# 5890                                                NaN
# 5891                                                NaN
# 5892                                                NaN
#
#      UniProt (TrEMBL) Submitted Name of Target Chain  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 5888                                             NaN
# 5889                                             NaN
# 5890                                             NaN
# 5891                                             NaN
# 5892                                             NaN
#
#      UniProt (TrEMBL) Entry Name of Target Chain  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 5888                                         NaN
# 5889                                         NaN
# 5890                                         NaN
# 5891                                         NaN
# 5892                                         NaN
#
#       UniProt (TrEMBL) Primary ID of Target Chain  \
# 0                                      A0A024QZ26
# 1                                      A0A024QZ26
# 2                                      A0A024QZ26
# 3                                      A0A024QZ26
# 4                                      A0A024QZ26
# ...                                           ...
# 5888                                   A0A024QZ26
# 5889                                   A0A024QZ26
# 5890                                   A0A024QZ26
# 5891                                   A0A024QZ26
# 5892                                   A0A024QZ26
#
#       UniProt (TrEMBL) Secondary ID(s) of Target Chain  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 5888                                               NaN
# 5889                                               NaN
# 5890                                               NaN
# 5891                                               NaN
# 5892                                               NaN
#
#      UniProt (TrEMBL) Alternative ID(s) of Target Chain
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5888                                                NaN
# 5889                                                NaN
# 5890                                                NaN
# 5891                                                NaN
# 5892                                                NaN
#
# [5893 rows x 48 columns]

# %%
df.to_csv('preprocessed.csv')

# %%
df['Ligand SMILES'][1]
# Out:
# 'Cl.CC(=O)Nc1ccc(cc1)-c1ccnc(Nc2ccc(NC(=O)CCCCCCC(=O)NO)cc2)n1'

# %%
import streamlit as st
from stmol import showmol
import py3Dmol

from rdkit import Chem
from rdkit.Chem import AllChem

st.title('RDKit + Py3DMOL 😀')

def makeblock(smi):
    mol = Chem.MolFromSmiles(smi)
    mol = Chem.AddHs(mol)
    AllChem.EmbedMolecule(mol)
    mblock = Chem.MolToMolBlock(mol)
    return mblock

def render_mol(xyz):
    xyzview = py3Dmol.view()#(width=400,height=400)
    xyzview.addModel(xyz,'mol')
    xyzview.setStyle({'stick':{}})
    xyzview.setBackgroundColor('white')
    xyzview.zoomTo()
    showmol(xyzview,height=500,width=500)

compound_smiles=st.text_input('SMILES please','CC')
blk=makeblock(compound_smiles)
render_mol(blk)
# Out:
# 2023-04-08 23:46:28.048 INFO    rdkit: Enabling RDKit 2022.09.5 jupyter extensions
# 2023-04-08 23:46:29.208
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
